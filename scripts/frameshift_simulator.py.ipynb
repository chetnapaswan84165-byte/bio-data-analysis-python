# %%
# Input DNA sequence
# Output convert to RNA
#Output generate codons in frames  and print codons for each frame clearly.

# %%
def dna_to_rna(dna):
    rna = ""
    for nucleotide in dna:
        if nucleotide  == "A":
            rna += "U"
         
        elif nucleotide == "T":
            rna += "A"
        elif nucleotide == "G":
            rna += "C"
        elif nucleotide == "C":
            rna += "G"
    return rna

def get_codons_in_frame(rna, start):
    codons = []
    for i in range(start, len(rna), 3):
        codon = rna[i:i+3]
        if len(codon) == 3:
            codons.append(codon)
    return codons

dna_sequence = input("Enter DNA sequence:")
rna_sequence = dna_to_rna(dna_sequence)

print("RNA sequence:", rna_sequence)

for frame in range(3):
    print(f"\nFrame{frame +1}:")
    codons = get_codons_in_frame(rna_sequence, frame)
    for c in codons:
        print(c)
# Out:
# Enter DNA sequence:TACGTATTAGCG
# RNA sequence: AUGCAUAAUCGC
#
# Frame1:
# AUG
# CAU
# AAU
# CGC
#
# Frame2:
# UGC
# AUA
# AUC
#
# Frame3:
# GCA
# UAA
# UCG

# %%
# Randomly delete one nucleotide 
# Recompute reading frames
# Print before and after comparisons

# %%
# This is written by me 
import random
def dna_to_rna(dna):
    rna = ""
    for nucleotide in dna:
        if nucleotide == "A":
            rna += "U"
        elif nucleotide == "T":
            rna += "A"
        elif nucleotide == "G":
            rna += "C"
        elif nucleotide == "C":
            rna += "G"
    return rna

def get_codons_in_frame(rna, start):
    codons = []
    for i in range(start, len(rna), 3):
        codon = rna[i:i+3]
        if len(codon) == 3:
            codons.append(codon)
    return codons     


def rna_mutation(rna):
    rna_list = list(rna)
    position = random.randint(0, len(rna_list)-1)
    
    original = rna_list[position]
    nucleotides = rna_list
    nucleotides.remove(original)
    
    rna_list[position] = random.choice(rna)
    mutated_rna = "".join(rna_list)
    return position, original, mutated_rna

dna_sequence = input("Enter DNA sequence:")
rna_sequence = dna_to_rna(dna_sequence)
pos, original, mutated = rna_mutation(rna_sequence)




print("DNA sequence:", dna_sequence)
print("RNA sequence:", rna_sequence)
print("Mutated RNA sequence:", mutated)
print("Mutation position:", pos)
print("Original nucleotide:", original)

for frame in range(3):
    print(f"\nframe{frame+1}:")
    codons = get_codons_in_frame(rna_sequence, frame)
    for c in codons:
        print(c)
# Out:
# Enter DNA sequence:ATCGTACCGAAT
# DNA sequence: ATCGTACCGAAT
# RNA sequence: UAGCAUGGCUUA
# Mutated RNA sequence: UAGUUGGCUUA
# Mutation position: 3
# Original nucleotide: C
#
# frame1:
# UAG
# CAU
# GGC
# UUA
#
# frame2:
# AGC
# AUG
# GCU
#
# frame3:
# GCA
# UGG
# CUU

# %%
import random

def dna_to_rna(dna):
    rna = ""
    for nucleotide in dna:
        if nucleotide == "A":
            rna += "U"
        elif nucleotide == "C":
            rna += "G"
        elif nucleotide == "G":
            rna += "C"
        elif nucleotide == "T":
            rna += "A"
    return rna



def get_codons_in_frame(rna, start):
    codons = []
    for i in range(start, len(rna), 3):
        codon = rna[i:i+3]
        if len(codon) == 3:
            codons.append(codon)
    return codons

def rna_mutation(rna):
    rna_list = list(rna)
    position = random.randint(0, len(rna_list)-1)
    
    original = rna_list[position]
    nucleotides = ["A", "U", "G","C"]
    nucleotides.remove(original)
    
    rna_list[position] = random.choice(nucleotides)
    mutated_rna = "".join(rna_list)
  
    return position, original, mutated_rna


dna_sequence = input("Enter DNA sequence:")
rna_sequence = dna_to_rna(dna_sequence)
pos, original, mutated = rna_mutation(rna_sequence)

print("DNA sequence:", dna_sequence)
print("RNA sequence:", rna_sequence)
print("Mutated RNA sequence:", mutated)
print("Mutation Position:", pos)
print("Original nucleotide:",original)


print("\nReading frames After mutation:")
for frame in range(3):
    print(f"\nFrame {frame +1}:")
    codons = get_codons_in_frame(mutated, frame)
    for c in codons:
        print(c)
# Out:
# Enter DNA sequence:TACTTAAGGCCAACT
# DNA sequence: TACTTAAGGCCAACT
# RNA sequence: AUGAAUUCCGGUUGA
# Mutated RNA sequence: AUGAAUCCCGGUUGA
# Mutation Position: 6
# Original nucleotide: U
#
# Reading frames After mutation:
#
# Frame 1:
# AUG
# AAU
# CCC
# GGU
# UGA
#
# Frame 2:
# UGA
# AUC
# CCG
# GUU
#
# Frame 3:
# GAA
# UCC
# CGG
# UUG

# %%
import random
def dna_to_rna(dna):
    rna = ""
    for nucleotide in dna:
        if nucleotide == "A":
            rna += "U"
        elif nucleotide == "T":
            rna += "A"
        elif nucleotide == "G":
            rna += "C"
        elif nucleotide == "C":
            rna += "G"
    return rna

def get_codons_in_frame(rna, start):
    codons = []
    for i in range(start, len(rna), 3):
        codon = rna[i:i+3]
        if len(codon) == 3:
            codons.append(codon)
    return codons     


def rna_mutation(rna):
    rna_list = list(rna)
    position = random.randint(0, len(rna_list)-1)
    
    original = rna_list[position]
    nucleotides = ["A", "U", "G","C"]
    nucleotides.remove(original)
    
    rna_list[position] = random.choice(nucleotides)
    mutated_rna = "".join(rna_list)
    return position, original, mutated_rna

dna_sequence = input("Enter DNA sequence:")
rna_sequence = dna_to_rna(dna_sequence)
pos, original, mutated = rna_mutation(rna_sequence)




print("DNA sequence:", dna_sequence)
print("RNA sequence:", rna_sequence)
print("Mutated RNA sequence:", mutated)
print("Mutation position:", pos)
print("Original nucleotide:", original)

print("\nReading frames AFTER mutation:")
for frame in range(3):
    print(f"\nframe{frame+1}:")
    codons = get_codons_in_frame(mutated, frame)
    for c in codons:
        print(c)
# Out:
# Enter DNA sequence:TACCGGTTAAGT
# DNA sequence: TACCGGTTAAGT
# RNA sequence: AUGGCCAAUUCA
# Mutated RNA sequence: AUGGCAAAUUCA
# Mutation position: 5
# Original nucleotide: C
#
# Reading frames AFTER mutation:
#
# frame1:
# AUG
# GCA
# AAU
# UCA
#
# frame2:
# UGG
# CAA
# AUU
#
# frame3:
# GGC
# AAA
# UUC
