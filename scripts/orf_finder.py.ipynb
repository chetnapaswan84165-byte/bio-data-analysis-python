# %% [markdown]
# # Write code to scan an RNA sequence
# # Write code to Detect all ORFs
# # Return start index, stop index, and protein sequence

# %%
# Input :- RNA sequence
# Process:- step 1. Detect every "AUG", 
#           step 2. Translate codon into amino acid until STOP codon(UAA, UGA, UAG)
# Output:- Frame, start position, stop position and protein sequence

# %%
# Hint:- Need to create nested loops, frame aware scanning, careful indexing.

# %%
rna_sequence = input("Enter RNA sequence:").upper()
codon_table = {"AUG":"Met(M)", "UUU":"Phe(F)", "UUC":"Phe(F)", "UUA": "Leu(L)", "UUG":"Leu(L)", "ACC":"Thr(T)", "ACU":"Thr(T)", "ACA":"Thr(T)", "ACG":"Thr(T)", "UGG":"Trp(W)","UAA":"STOP", "UAG":"STOP", "UGA":"STOP"}




def spilit_codons_by_frame(rna, frame):
    codons = []
    for i in range(frame, len(rna), 3):
        codon = rna[i:i+3]
        if len(codon) == 3:
            codons.append(codon)
    return codons


def find_orfs(rna, codon_table):
    orfs = []
    
    for frame in range(3):
        i = frame
        while i<= len(rna) - 3:
            codon = rna[i:i+3]
            
            if codon == "AUG":
                protein = ""
                start = i
                
                j = i
                while j<= len(rna) -3:
                    current_codon = rna[j:j+3]
                    amino_acid = codon_table.get(current_codon)
                    
                    if amino_acid == "STOP":
                        orfs.append({"frame": frame + 1, "start": start, "stop": j + 2, "protein": protein})
                        break
                        
                    if amino_acid:
                        protein += amino_acid
                        
                    j += 3
                    
                i = j
            else:
                i += 3
             
    return orfs     





orfs = find_orfs(rna_sequence, codon_table)

if not orfs:
    print("No ORFs found")
    
for orf in orfs:
    print("\nORF found")
    print("Frame:", orf["frame"])
    print("Start:",orf["start"])
    print("Stop:", orf["stop"])
    print("Protein:", orf["protein"])
    
for frame in range(3):
    codons = spilit_codons_by_frame(rna_sequence, frame)
    protein = translate_codons(codons, codon_table)    
    print(f"\nFrame {frame +1}")
    print("Codon:", codons)
    print("Protein:", protein if protein else "Non fuctional protein")
# Out:
# Enter RNA sequence:AUGUUUUGGACCUGA
#
# ORF found
# Frame: 1
# Start: 0
# Stop: 14
# Protein: Met(M)Phe(F)Trp(W)Thr(T)
#
# Frame 1
# Codon: ['AUG', 'UUU', 'UGG', 'ACC', 'UGA']
# Protein: Met(M)Phe(F)Trp(W)Thr(T)
#
# Frame 2
# Codon: ['UGU', 'UUU', 'GGA', 'CCU']
# Protein: Phe(F)
#
# Frame 3
# Codon: ['GUU', 'UUG', 'GAC', 'CUG']
# Protein: Leu(L)

# %%
rna_sequence = input("Enter RNA sequence:").upper()
codon_table = {"AUG":"Met(M)", "UUU":"Phe(F)", "UUC":"Phe(F)", "UUA": "Leu(L)", "UUG":"Leu(L)", "ACC":"Thr(T)", "ACU":"Thr(T)", "ACA":"Thr(T)", "ACG":"Thr(T)", "UGG":"Trp(W)","UAA":"STOP", "UAG":"STOP", "UGA":"STOP"}




def spilit_codons_by_frame(rna, frame):
    codons = []
    for i in range(frame, len(rna), 3):
        codon = rna[i:i+3]
        if len(codon) == 3:
            codons.append(codon)
    return codons


def find_orfs(rna, codon_table):
    orfs = []
    
    for frame in range(3):
        i = frame
        while i<= len(rna)-3:
            codon = rna[i:i+3]
            
            if codon == "AUG":
                protein = ""
                start = i
                
                j = i
                while j<= len(rna) -3:
                    current_codon = rna[j:j+3]
                    amino_acid = codon_table.get(current_codon)
                    
                    if amino_acid == "STOP":
                        orfs.append({"frame": frame + 1, "start": start, "stop": j + 2, "protein": protein})
                        break
                        
                    if amino_acid:
                        protein += amino_acid
                        
                    j += 3
                    
                i = j
            else:
                i += 3
             
    return orfs     



def translate_codons(codons, codon_table):
    protein = ""
    for codon in codons:
        amino_acid = codon_table.get(codon)
        if amino_acid == "STOP":
            break
        if amino_acid:
            protein += amino_acid
    return protein  


orfs = find_orfs(rna_sequence, codon_table)

if not orfs:
    print("No ORFs found")
    
for orf in orfs:
    print("\nORF found")
    print("Frame:", orf["frame"])
    print("Start:",orf["start"])
    print("Stop:", orf["stop"])
    print("Protein:", orf["protein"])
    
for frame in range(3):
    codons = spilit_codons_by_frame(rna_sequence, frame)
    protein = translate_codons(codons, codon_table)    
    print(f"\nFrame {frame +1}")
    print("Codon:", codons)
    print("Protein:", protein if protein else "Non fuctional protein")
# Out:
# Enter RNA sequence:AUGUUUUUGUGGACUUAA
#
# ORF found
# Frame: 1
# Start: 0
# Stop: 17
# Protein: Met(M)Phe(F)Leu(L)Trp(W)Thr(T)
#
# Frame 1
# Codon: ['AUG', 'UUU', 'UUG', 'UGG', 'ACU', 'UAA']
# Protein: Met(M)Phe(F)Leu(L)Trp(W)Thr(T)
#
# Frame 2
# Codon: ['UGU', 'UUU', 'UGU', 'GGA', 'CUU']
# Protein: Phe(F)
#
# Frame 3
# Codon: ['GUU', 'UUU', 'GUG', 'GAC', 'UUA']
# Protein: Phe(F)Leu(L)

# %%
rna_sequence = input("Enter RNA sequence:").upper()
codon_table = {"AUG":"Met(M)", "UUU":"Phe(F)", "UUC":"Phe(F)", "UUA": "Leu(L)", "UUG":"Leu(L)", "ACC":"Thr(T)", "ACU":"Thr(T)", "ACA":"Thr(T)", "ACG":"Thr(T)", "UGG":"Trp(W)","UAA":"STOP", "UAG":"STOP", "UGA":"STOP"}




def spilit_codons_by_frame(rna, frame):
    codons = []
    for i in range(frame, len(rna), 3):
        codon = rna[i:i+3]
        if len(codon) == 3:
            codons.append(codon)
    return codons


def find_orfs(rna, codon_table):
    orfs = []
    
    for frame in range(3):
        i = frame
        while i<= len(rna)-3:
            codon = rna[i:i+3]
            
            if codon == "AUG":
                protein = ""
                start = i
                
                j = i
                while j<= len(rna) -3:
                    current_codon = rna[j:j+3]
                    amino_acid = codon_table.get(current_codon)
                    
                    if amino_acid == "STOP":
                        orfs.append({"frame": frame + 1, "start": start, "stop": j + 2, "protein": protein})
                        break
                        
                    if amino_acid:
                        protein += amino_acid
                        
                    j += 3
                    
                i = j
            else:
                i += 3
             
    return orfs     




orfs = find_orfs(rna_sequence, codon_table)

if not orfs:
    print("No ORFs found")
    
for orf in orfs:
    print("\nORF found")
    print("Frame:", orf["frame"])
    print("Start:",orf["start"])
    print("Stop:", orf["stop"])
    print("Protein:", orf["protein"])
# Out:
# Enter RNA sequence:UUUUUAACUUGGGUGA
# No ORFs found

# %%
rna_sequence = input("Enter RNA sequence:").upper()
codon_table = {"AUG":"Met(M)", "UUU":"Phe(F)", "UUC":"Phe(F)", "UUA": "Leu(L)", "UUG":"Leu(L)", "ACC":"Thr(T)", "ACU":"Thr(T)", "ACA":"Thr(T)", "ACG":"Thr(T)", "UGG":"Trp(W)","UAA":"STOP", "UAG":"STOP", "UGA":"STOP"}




def spilit_codons_by_frame(rna, frame):
    codons = []
    for i in range(frame, len(rna), 3):
        codon = rna[i:i+3]
        if len(codon) == 3:
            codons.append(codon)
    return codons


def find_orfs(rna, codon_table):
    orfs = []
    
    for frame in range(3):
        i = frame
        while i<= len(rna)-3:
            codon = rna[i:i+3]
            
            if codon == "AUG":
                protein = ""
                start = i
                
                j = i
                while j<= len(rna) -3:
                    current_codon = rna[j:j+3]
                    amino_acid = codon_table.get(current_codon)
                    
                    if amino_acid == "STOP":
                        orfs.append({"frame": frame + 1, "start": start, "stop": j + 2, "protein": protein})
                        break
                        
                    if amino_acid:
                        protein += amino_acid
                        
                    j += 3
                    
                i = j
            else:
                i += 3
             
    return orfs     



def translate_codons(codons, codon_table):
    protein = ""
    for codon in codons:
        amino_acid = codon_table.get(codon)
        if amino_acid == "STOP":
            break
        if amino_acid:
            protein += amino_acid
    return protein  


orfs = find_orfs(rna_sequence, codon_table)

if not orfs:
    print("No ORFs found")
    
for orf in orfs:
    print("\nORF found")
    print("Frame:", orf["frame"])
    print("Start:",orf["start"])
    print("Stop:", orf["stop"])
    print("Protein:", orf["protein"])
    
for frame in range(3):
    codons = spilit_codons_by_frame(rna_sequence, frame)
    protein = translate_codons(codons, codon_table)    
    print(f"\nFrame {frame +1}")
    print("Codon:", codons)
    print("Protein:", protein if protein else "Non fuctional protein")
# Out:
# Enter RNA sequence:AUGUGAUUUUUGAUGAUGACCAUGACGAUGUAG
#
# ORF found
# Frame: 1
# Start: 0
# Stop: 5
# Protein: Met(M)
#
# ORF found
# Frame: 1
# Start: 12
# Stop: 32
# Protein: Met(M)Met(M)Thr(T)Met(M)Thr(T)Met(M)
#
# Frame 1
# Codon: ['AUG', 'UGA', 'UUU', 'UUG', 'AUG', 'AUG', 'ACC', 'AUG', 'ACG', 'AUG', 'UAG']
# Protein: Met(M)
#
# Frame 2
# Codon: ['UGU', 'GAU', 'UUU', 'UGA', 'UGA', 'UGA', 'CCA', 'UGA', 'CGA', 'UGU']
# Protein: Phe(F)
#
# Frame 3
# Codon: ['GUG', 'AUU', 'UUU', 'GAU', 'GAU', 'GAC', 'CAU', 'GAC', 'GAU', 'GUA']
# Protein: Phe(F)

# %% [markdown]
# # input:- RNA sequence
# # Process:- 1. Randomly generate one random point mutation by removing randomly nucleotide or codon
# # 2. Find ORFs for both
# # Output:- compare Number of orfs, length of orf, protein sequence difference

# %%
rna_sequence = input("Enter RNA sequence:").upper()

codon_table = {"AUG":"Met(M)", "UUU":"Phe(F)", "UUC":"Phe(F)", "UUA": "Leu(L)", "UUG":"Leu(L)", "ACC":"Thr(T)", "ACU":"Thr(T)", "ACA":"Thr(T)", "ACG":"Thr(T)", "UGG":"Trp(W)","UAA":"STOP", "UAG":"STOP", "UGA":"STOP"}


import random

def spilit_codons_by_frame(rna, frame):
    codons = []
    for i in range(frame, len(rna), 3):
        codon = rna[i:i+3]
        if len(codon) == 3:
            codons.append(codon)
    return codons


def find_orfs(rna, codon_table):
    orfs = []
    
    for frame in range(3):
        i = frame
        while i<= len(rna)-3:
            codon = rna[i:i+3]
            
            if codon == "AUG":
                protein = ""
                start = i
                
                j = i
                while j<= len(rna) -3:
                    current_codon = rna[j:j+3]
                    amino_acid = codon_table.get(current_codon)
                    
                    if amino_acid == "STOP":
                        orfs.append({"frame": frame + 1, "start": start, "stop": j + 2, "protein": protein})
                        break
                        
                    if amino_acid:
                        protein += amino_acid
                        
                    j += 3
                    
                i = j
            else:
                i += 3
             
    return orfs  

orfs = find_orfs(rna_sequence, codon_table)

if not orfs:
    print("No ORFs found")
    
for orf in orfs:
    print("\nORF found")
    print("Frame:", orf["frame"])
    print("Start:",orf["start"])
    print("Stop:", orf["stop"])
    print("Protein:", orf["protein"])





def rna_mutation(rna):
    rna_sequence = list(rna)
    position = random.randint(0, len(rna_sequence) - 1)
    
    original = rna_sequence[position]
    nucleotides = ["A","U","G","C"]
    nucleotides.remove(original)
    
    rna_sequence[position] = random.choice(nucleotides)
    mutated_rna = "".join(rna_sequence)
    return position, original, mutated_rna



def find_mutated_orfs(mutated_rna, codon_table):
    mutated_orfs = []
    
    for frame in range(3):
        i = frame
        while i<= len(mutated_rna)-3:
            codon = mutated_rna[i:i+3]
            
            if codon == "AUG":
                protein = ""
                start = i
                
                j = i
                while j<= len(mutated_rna) -3:
                    current_codon = mutated_rna[j:j+3]
                    amino_acid = codon_table.get(current_codon)
                    
                    if amino_acid == "STOP":
                        mutated_orfs.append({"frame": frame + 1, "start": start, "stop": j + 2, "protein": protein})
                        break
                    
                        
                    if amino_acid:
                        protein += amino_acid
                        
                    j += 3
                    
                i = j
            else:
                i += 3
             
    return mutated_orfs 


mutated_orfs = find_mutated_orfs(mutated_rna, codon_table)
print("Mutated ORFs", mutated_orfs)
    

    
pos, original, mutated_rna = rna_mutation(rna_sequence)
print("Mutation position:", pos)
print("Original nucleotide:", original)
print("Mutated RNA:", mutated_rna)     

for mutated_orf in mutated_orfs:
    print("\nORF found")
    print("Frame:", mutated_orf["frame"])
    print("Start:",mutated_orf["start"])
    print("Stop:", mutated_orf["stop"])
    print("Protein:", mutated_orf["protein"])
# Out:
# Enter RNA sequence:AUGUUUUGGAUCUUCAUGUAA
#
# ORF found
# Frame: 1
# Start: 0
# Stop: 20
# Protein: Met(M)Phe(F)Trp(W)Phe(F)Met(M)
# Mutated ORFs [{'frame': 1, 'start': 0, 'stop': 23, 'protein': 'Met(M)Phe(F)Trp(W)Met(M)Phe(F)Met(M)'}]
# Mutation position: 6
# Original nucleotide: U
# Mutated RNA: AUGUUUGGGAUCUUCAUGUAA
#
# ORF found
# Frame: 1
# Start: 0
# Stop: 23
# Protein: Met(M)Phe(F)Trp(W)Met(M)Phe(F)Met(M)

# %%
rna = input("Enter RNA sequence:").upper()
codon_table = {"AUG":"Met(M)", "UUU":"Phe(F)", "UUC":"Phe(F)", "UUA": "Leu(L)", "UUG":"Leu(L)", "ACC":"Thr(T)", "ACU":"Thr(T)", "ACA":"Thr(T)", "ACG":"Thr(T)", "UGG":"Trp(W)","UAA":"STOP", "UAG":"STOP", "UGA":"STOP"}

import random 



def spilit_codons_by_frame(rna, frame):
    codons = []
    for i in range(frame, len(rna), 3):
        codon = rna[i:i+3]
        if len(codon) == 3:
            codons.append(codon)
    return codons



def find_orfs(rna, codon_table):
    orfs = []
    
    for frame in range(3):
        i = frame
        while i<= len(rna)-3:
            codon = rna[i:i+3]
            
            if codon == "AUG":
                protein = ""
                start = i
                
                j = i
                while j<= len(rna) -3:
                    current_codon = rna[j:j+3]
                    amino_acid = codon_table.get(current_codon)
                    
                    if amino_acid == "STOP":
                        orfs.append({"frame": frame + 1, "start": start, "stop": j + 2, "protein": protein})
                        break
                        
                    if amino_acid:
                        protein += amino_acid
                        
                    j += 3
                    
                i = j
            else:
                i += 3
             
    return orfs     




orfs = find_orfs(rna, codon_table)

if not orfs:
    print("No ORFs found")
    
for orf in orfs:
    print("\nORF found")
    print("Frame:", orf["frame"])
    print("Start:",orf["start"])
    print("Stop:", orf["stop"])
    print("Protein:", orf["protein"])
    

    
    
def rna_deletion_mutation(rna):
    rna = list(rna)
    position = random.randint(0, len(rna) - 1)
    deleted = rna.pop(position)
    return position, deleted, "".join(rna)


pos, deleted, mutated_rna = rna_deletion_mutation(rna)
print("Mutation position:", pos)
print("Deletion of:", deleted)
print("Mutated RNA:", mutated_rna)


   


def find_mutated_orfs(mutated_rna, codon_table):
    mutated_orfs = []
    
    for frame in range(3):
        i = frame
        while i<= len(mutated_rna)-3:
            codon = mutated_rna[i:i+3]
            
            if codon == "AUG":
                protein = ""
                start = i
                
                j = i
                while j<= len(mutated_rna) -3:
                    current_codon = mutated_rna[j:j+3]
                    amino_acid = codon_table.get(current_codon)
                    
                    if amino_acid == "STOP":
                        mutated_orfs.append({"frame": frame + 1, "start": start, "stop": j + 2, "protein": protein})
                        break
                    
                        
                    if amino_acid:
                        protein += amino_acid
                        
                    j += 3
                    
                i = j
            else:
                i += 3
             
    return mutated_orfs 


mutated_orfs = find_mutated_orfs(mutated_rna, codon_table)
print("Mutated ORFs", mutated_orfs)
    
for mutated_orf in mutated_orfs:
    print("\nORF found")
    print("Frame:", mutated_orf["frame"])
    print("Start:",mutated_orf["start"])
    print("Stop:", mutated_orf["stop"])
    print("Protein:", mutated_orf["protein"])
    

print("\n----COMPARISION REPORT----") 
print("Normal ORFs:", len(orfs))
print("Mutated ORFs:", len(mutated_orfs))



if orfs:
    normal_longest = max(orfs, key=lambda x: len(x["protein"]))
    print("Longest normal protein length:", len(normal_longest["protein"]))
    
else:
    print("No normal ORFs")
    
    
if mutated_orfs:    
    mutated_longest = max(mutated_orfs, key=lambda x: len(x["protein"]))
    print("Longest mutated protein length:", len(mutated_longest["protein"]))
else:
    print("No mutated ORFs")
# Out:
# Enter RNA sequence:AUGUUUUGGUCCAUCAUGUUCUAA
#
# ORF found
# Frame: 1
# Start: 0
# Stop: 23
# Protein: Met(M)Phe(F)Trp(W)Met(M)Phe(F)
# Mutation position: 21
# Deletion of: U
# Mutated RNA: AUGUUUUGGUCCAUCAUGUUCAA
# Mutated ORFs []
#
# ----COMPARISION REPORT----
# Normal ORFs: 1
# Mutated ORFs: 0
# Longest normal protein length: 30
# No mutated ORFs
